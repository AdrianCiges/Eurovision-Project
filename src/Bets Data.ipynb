# %% [markdown]
# ### Odds 2015

# %%
import pandas as pd
apuestas_2015 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK','BETFAIR_EXCHANG'])
apuestas_2015
# Out:
#                                                  SONG  BET365  UNIBET  \
# 0                      Sweden Måns Zelmerlöw - Heroes     2.1     2.0
# 1           Russia Polina Gagarina - A Million Voices    3.75     4.5
# 2                        Italy Il Volo - Grande Amore       5     6.0
# 3                 Belgium Loïc Nottet - Rhythm Inside      11    12.0
# 4             Australia Guy Sebastian - Tonight Again      11    12.0
# 5         Estonia Born & Rästa - Goodbye to Yesterday      19    24.0
# 6          Serbia Bojana Stamenov - Beauty Never Lies      34    30.0
# 7       Norway Mørland & Scarlett - A Monster Like Me      34    30.0
# 8             Latvia Aminata Savadogo - Love Injected      41    51.0
# 9                     Israel Nadav Guedj - Golden Boy      67    51.0
# 10       Azerbaijan Elnur Hüseynov - Hour Of The Wolf      67    34.0
# 11                            Spain Edurne - Amanecer      81    34.0
# ...

# %%
paises_dobleword = {'North':'North Macedonia','The':'The Netherlands','Bosnia':'Bosnia and Herzegovina',
                    'United':'United Kingdom','Czech':'Czech Republic','Serbia':'Serbia and Montenegro',
                    'San':'San Marino'}

# %%
dict_codes = {  "Albania":10,
                "Andorra":11,
                "Armenia":12,
                "Australia":13,
                "Austria":14,
                "Azerbaijan":15,
                "Belarus":16,
                "Belgium":17,
                "Bosnia and Herzegovina":18,
                "Bulgaria":19,
                "Croatia":20,
                "Cyprus":21,
                "Czech Republic":22,
                "Denmark":23,
                "Estonia":24,
                "Finland":25,
                "France":26,
                "Georgia":27,
                "Germany":28,
                "Greece":29,
                "Hungary":30,
                "Iceland":31,
                "Ireland":32,
                "Israel":33,
                "Italy":34,
                "Latvia":35,
                "Lithuania":36,
                "Malta":37,
                "Moldova":38,
                "Monaco":39,
                "Montenegro":40,
                "North Macedonia":41,
                "Norway":42,
                "Poland":43,
                "Portugal":44,
                "Romania":45,
                "Russia":46,
                "San Marino":47,
                "Serbia":48,
                "Serbia and Montenegro":49,
                "Slovakia":50,
                "Slovenia":51,
                "Spain":52,
                "Sweden":53,
                "Switzerland":54,
                "The Netherlands":55,
                "Netherlands":55,
                "Turkey":56,
                "Ukraine":57,
                "United Kingdom":58
}

# %%
lista_corregida = []
for song in apuestas_2015['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2015['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2015['country']:
    codigo.append(int(str(dict_codes[pais])+'2015'))
apuestas_2015['codigo'] = codigo

# %%
apuestas_2015.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG', 'country',
#        'codigo'],
#       dtype='object')

# %%
ap15_bets = apuestas_2015[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG']]

# %%
apuestas_2015['bet_mean'] = list(ap15_bets.mean(axis=1))
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14728\2393030016.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   apuestas_2015['bet_mean'] = list(ap15_bets.mean(axis=1))

# %%
apuestas_2015.drop(['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG', 'SONG'], axis=1, inplace=True)

# %%
apuestas_2015
# Out:
#                   country  codigo    bet_mean
# 0                  Sweden  532015    2.077222
# 1                  Russia  462015    4.161111
# 2                   Italy  342015    5.444444
# 3                 Belgium  172015   10.750000
# 4               Australia  132015   11.444444
# 5                 Estonia  242015   22.888889
# 6   Serbia and Montenegro  492015   32.722222
# 7                  Norway  422015   40.352941
# 8                  Latvia  352015   55.235294
# 9                  Israel  332015   57.000000
# 10             Azerbaijan  152015   58.500000
# 11                  Spain  522015   69.352941
# 12               Slovenia  512015   81.277778
# 13                Georgia  272015  104.333333
# 14         United Kingdom  582015  114.666667
# 15                 Greece  292015  138.764706
# 16                Romania  452015  154.705882
# 17                Armenia  122015  135.722222
# 18                Albania  102015  177.055556
# ...

# %% [markdown]
# ### Odds 2016

# %%
apuestas_2016 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK','BETFAIR_EXCHANG','OTHER'])
apuestas_2016
# Out:
#                                                  SONG  BET365  UNIBET  \
# 0        Russia Sergey Lazarev - You Are the Only One    1.90     1.4
# 1                Australia Dami Im - Sound of Silence    2.75     6.0
# 2                               Ukraine Jamala - 1944   10.00    17.0
# 3                      Sweden Frans - If I Were Sorry   17.00    21.0
# 4                          France Amir - J'ai Cherché   17.00    34.0
# 5                  Armenia Iveta Mukuchyan - LoveWave   34.00    51.0
# 6                     Malta Ira Losco - Walk on Water   29.00    41.0
# 7          Bulgaria Poli Genova - If Love Was a Crime   81.00    26.0
# 8         United Kingdom J. & Jake - You're Not Alone   51.00    41.0
# 9                              Spain Barei - Say Yay!  151.00    17.0
# 10                  Netherlands Douwe Bob - Slow Down   51.00    81.0
# 11                           Austria Zoë - Loin d'ici   81.00   151.0
# ...

# %%
lista_corregida = []
for song in apuestas_2016['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2016['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2016['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2016['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2016['country']:
    codigo.append(int(str(dict_codes[pais])+'2016'))
apuestas_2016['codigo'] = codigo

# %%
apuestas_2016.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG', 'OTHER',
#        'country', 'codigo'],
#       dtype='object')

# %%
ap16_bets = apuestas_2016[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG', 'OTHER']]

# %%
apuestas_2016['bet_mean'] = list(ap16_bets.mean(axis=1))

# %%
apuestas_2016.drop(['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'BETFAIR_EXCHANG', 'OTHER', 'SONG'], axis=1, inplace=True)

# %%
apuestas_2016
# Out:
#                   country  codigo  bet_mean
# 0                  Russia  462016    1.6825
# 1               Australia  132016    3.8605
# 2                 Ukraine  572016   14.4375
# 3                  Sweden  532016   21.6500
# 4                  France  262016   24.9500
# 5                 Armenia  122016   41.8500
# 6                   Malta  372016   42.4000
# 7                Bulgaria  192016   76.9500
# 8          United Kingdom  582016   73.7000
# 9                   Spain  522016   86.4500
# 10            Netherlands  552016   86.6500
# 11                Austria  142016   96.5500
# 12                 Latvia  352016  104.7500
# 13                Belgium  172016  108.3500
# 14                  Italy  342016  114.7500
# 15                 Cyprus  212016  123.3500
# 16                 Israel  332016  127.6500
# 17                 Poland  432016  161.6500
# 18              Lithuania  362016  181.0500
# 19  Serbia and Montenegro  492016  191.6500
# ...

# %% [markdown]
# ### 2017

# %%
apuestas_2017 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK'])
apuestas_2017
# Out:
#                                               SONG   BET365  UNIBET  YOU_WIN  \
# 0        Bulgaria Kristian Kostov - Beautiful Mess     2.37    2.75      2.2
# 1       Portugal Salvador Sobral - Amar Pelos Dois     2.62    2.91      2.4
# 2    Italy Francesco Gabbani - Occidentali's Karma     6.50    8.00      7.0
# 3                    Belgium Blanche - City Lights     6.50    8.00      7.0
# 4     Romania Ilinca feat. Alex Florea - Yodel It!    19.00   19.00     17.0
# 5           Sweden Robin Bengtsson - I Can't Go On    26.00   26.00     26.0
# 6               Croatia Jacques Houdek - My Friend    51.00   26.00     51.0
# 7      United Kingdom Jones - Never Give Up on You    67.00   51.00     67.0
# 8            Moldova Sunstroke Project - Hey Mamma    67.00   41.00     51.0
# 9                            France Alma - Requiem   151.00   67.00    101.0
# 10                   Armenia Artsvik - Fly With Me   201.00   81.00    151.0
# ...

# %%
lista_corregida = []
for song in apuestas_2017['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2017['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2017['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2017['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2017['country']:
    codigo.append(int(str(dict_codes[pais])+'2017'))
apuestas_2017['codigo'] = codigo

# %%
apuestas_2017.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'country', 'codigo'],
#       dtype='object')

# %%
ap17_bets = apuestas_2017[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK']]

# %%
apuestas_2017['bet_mean'] = list(ap17_bets.mean(axis=1))

# %%
apuestas_2017.drop(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK'], axis=1, inplace=True)

# %%
apuestas_2017
# Out:
#            country  codigo    bet_mean
# 0         Bulgaria  192017    2.707778
# 1         Portugal  442017    2.757222
# 2            Italy  342017    6.979444
# 3          Belgium  172017    8.444444
# 4          Romania  452017   19.777778
# 5           Sweden  532017   23.777778
# 6          Croatia  202017   42.444444
# 7   United Kingdom  582017   49.277778
# 8          Moldova  382017   50.555556
# 9           France  262017  117.111111
# 10         Armenia  122017  126.777778
# 11          Norway  422017  122.833333
# 12     Netherlands  552017  145.888889
# 13       Australia  132017  180.555556
# 14         Denmark  232017  199.941176
# 15      Azerbaijan  152017  192.500000
# 16         Hungary  302017  216.722222
# 17         Germany  282017  217.777778
# 18          Poland  432017  253.055556
# 19          Greece  292017  259.166667
# 20         Austria  142017  261.944444
# 21         Belarus  162017  289.722222
# 22          Cyprus  212017  283.055556
# ...

# %% [markdown]
# ### 2018

# %%
apuestas_2018 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN', 'other'])
apuestas_2018
# Out:
#                                               SONG   BET365  UNIBET  YOU_WIN  \
# 0                    Cyprus Eleni Foureira - Fuego     2.00    2.15      2.2
# 1                               Israel Netta - Toy     3.25    3.60      3.5
# 2       Germany M. Schulte - You Let Me Walk Alone     7.50    8.50      6.5
# 3            Ireland Ryan O'Shaughnessy - Together    17.00   19.00     13.0
# 4               Estonia Elina Nechayeva - La Forza    34.00   26.00     26.0
# 5         Sweden Benjamin Ingrosso - Dance You Off    41.00   40.00     41.0
# 6      Lithuania I. Zasimauskaitė - When We're Old    51.00   55.00     41.0
# 7                     United Kingdom SuRie - Storm    51.00   41.00     34.0
# 8       Norway Rybak - That's How You Write a Song    81.00   60.00     81.0
# 9                   France Madame Monsieur - Mercy   101.00   60.00     51.0
# 10   Italy Meta & Moro - Non Mi Avete Fatto Niente   101.00   70.00     41.0
# ...

# %%
apuestas_2018.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'other'],
#       dtype='object')

# %%
lista_corregida = []
for song in apuestas_2018['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2018['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2018['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2018['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2018['country']:
    codigo.append(int(str(dict_codes[pais])+'2018'))
apuestas_2018['codigo'] = codigo

# %%
ap18_bets = apuestas_2018[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'other']]

# %%
apuestas_2018['bet_mean'] = list(ap18_bets.mean(axis=1))

# %%
apuestas_2018.drop(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'other'], axis=1, inplace=True)

# %%
apuestas_2018
# Out:
#                   country  codigo    bet_mean
# 0                  Cyprus  212018    2.221667
# 1                  Israel  332018    3.380556
# 2                 Germany  282018    9.383333
# 3                 Ireland  322018   14.666667
# 4                 Estonia  242018   28.000000
# 5                  Sweden  532018   36.166667
# 6               Lithuania  362018   41.944444
# 7          United Kingdom  582018   47.388889
# 8                  Norway  422018   56.222222
# 9                  France  262018   69.333333
# 10                  Italy  342018   85.388889
# 11              Australia  132018   78.333333
# 12                Finland  252018   87.111111
# 13         Czech Republic  222018  106.333333
# 14                Moldova  382018  109.277778
# 15               Bulgaria  192018  126.277778
# 16                Denmark  232018  144.333333
# 17                Hungary  302018  133.388889
# 18            Netherlands  552018  164.944444
# ...

# %% [markdown]
# ### 2019

# %%
apuestas_2019 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK'])
apuestas_2019
# Out:
#                                               SONG  BET365  UNIBET  YOU_WIN  \
# 0             Netherlands Duncan Laurence - Arcade     1.5    1.63     1.55
# 1                            Italy Mahmood - Soldi     5.0    8.00     8.00
# 2              Switzerland Luca Hänni - She Got Me     6.0   13.00    11.00
# 3      Australia Kate Miller-Heidke - Zero Gravity    11.0   14.00    13.00
# 4          Sweden John Lundvik - Too Late for Love    15.0   17.00    15.00
# 5                Norway KEiiNO - Spirit in the Sky    34.0   25.00    21.00
# 6                       Azerbaijan Chingiz - Truth    34.0   33.00    51.00
# 7                   Russia Sergey Lazarev - Scream    41.0   50.00    51.00
# 8                Iceland Hatari - Hatrið mun sigra    51.0   40.00    51.00
# 9                       France Bilal Hassani - Roi    67.0   75.00    51.00
# 10               Denmark Leonora - Love Is Forever   151.0  100.00   151.00
# ...

# %%
lista_corregida = []
for song in apuestas_2019['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2019['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2019['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2019['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2019['country']:
    codigo.append(int(str(dict_codes[pais])+'2019'))
apuestas_2019['codigo'] = codigo

# %%
apuestas_2019.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'country', 'codigo'],
#       dtype='object')

# %%
ap19_bets = apuestas_2019[['UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK']]

# %%
apuestas_2019['bet_mean'] = list(ap19_bets.mean(axis=1))

# %%
apuestas_2019.drop(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN','MATCH_BOOK'], axis=1, inplace=True)

# %%
apuestas_2019
# Out:
#                   country  codigo    bet_mean
# 0             Netherlands  552019    1.677647
# 1                   Italy  342019    9.294118
# 2             Switzerland  542019   10.147059
# 3               Australia  132019   11.470588
# 4                  Sweden  532019   16.294118
# 5                  Norway  422019   26.882353
# 6              Azerbaijan  152019   33.294118
# 7                  Russia  462019   41.588235
# 8                 Iceland  312019   49.764706
# 9                  France  262019   58.823529
# 10                Denmark  232019   92.058824
# 11                 Cyprus  212019   93.764706
# 12                Estonia  242019  129.294118
# 13                  Spain  522019  134.588235
# 14        North Macedonia  412019  161.941176
# 15         Czech Republic  222019  165.176471
# 16                  Malta  372019  188.470588
# 17                 Greece  292019  191.058824
# 18  Serbia and Montenegro  492019  225.764706
# ...

# %% [markdown]
# ### 2021

# %%
apuestas_2021 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK','other'])
apuestas_2021
# Out:
#                                               SONG  BET365  UNIBET  YOU_WIN  \
# 0                   Italy Måneskin - Zitti e buoni    3.25    3.25     2.75
# 1                     France Barbara Pravi - Voilà    3.25    3.25     4.50
# 2                      Malta Destiny - Je Me Casse    5.00    5.00     5.50
# 3                              Ukraine Go_A - Shum   17.00   18.00     8.00
# 4                Finland Blind Channel - Dark Side   15.00   11.00    21.00
# 5        Switzerland Gjon's Tears - Tout l'univers   17.00   18.00    11.00
# 6            Iceland Daði & Gagnamagnið - 10 Years   17.00   21.00    17.00
# 7                  Lithuania The Roop - Discoteque   41.00   51.00    61.00
# 8                            Sweden Tusse - Voices   41.00   51.00    91.00
# 9    San Marino Senhit feat. Flo Rida - Adrenalina   67.00   81.00    67.00
# 10                       Norway TIX - Fallen Angel   67.00   81.00   126.00
# ...

# %%
lista_corregida = []
for song in apuestas_2021['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2021['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2021['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2021['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2021['country']:
    if pais == '"':
        lista_corregida.append('Switzerland')
    else:
        lista_corregida.append(pais)
apuestas_2021['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2021['country']:
    codigo.append(int(str(dict_codes[pais])+'2021'))
apuestas_2021['codigo'] = codigo

# %%
apuestas_2021.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'other', 'country', 'codigo'],
#       dtype='object')

# %%
ap21_bets = apuestas_2021[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'other']]

# %%
apuestas_2021['bet_mean'] = list(ap21_bets.mean(axis=1))

# %%
apuestas_2021.drop(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'other'], axis=1, inplace=True)

# %%
apuestas_2021
# Out:
#                   country  codigo    bet_mean
# 0                   Italy  342021    3.212632
# 1                  France  262021    3.878947
# 2                   Malta  372021    5.102632
# 3                 Ukraine  572021   14.105263
# 4                 Finland  252021   16.078947
# 5             Switzerland  542021   16.052632
# 6                 Iceland  312021   17.631579
# 7               Lithuania  362021   44.210526
# 8                  Sweden  532021   45.105263
# 9              San Marino  472021   61.473684
# 10                 Norway  422021   69.947368
# 11               Portugal  442021   78.421053
# 12               Bulgaria  192021   86.947368
# 13                 Cyprus  212021  104.210526
# 14             Azerbaijan  152021  127.052632
# 15                 Greece  292021  154.210526
# 16                 Russia  462021  171.000000
# 17  Serbia and Montenegro  492021  215.473684
# 18                 Israel  332021  260.210526
# ...

# %% [markdown]
# ### 2022

# %%
apuestas_2022 = pd.read_clipboard(header=None, names=['SONG','BET365','UNIBET','YOU_WIN','BOYLE_SPORTS','CORAL',
                                                     'SKY_BET','BET_VICTOR','TITAN_BET','PAF','BETFAIR_SPORT',
                                                     'SPORTING_BET','INTE_TOPS','PADDY_POWER','BET_FRED','BETWAY',
                                                     'STAN_JAMES','BWIN','MATCH_BOOK'])
apuestas_2022
# Out:
#                                               SONG   BET365  UNIBET  YOU_WIN  \
# 0              Ukraine Kalush Orchestra - Stefania     1.25    1.22     1.29
# 1          Sweden Cornelia Jakobs - Hold Me Closer     5.00    5.10     7.25
# 2                             Spain Chanel - SloMo    10.00   13.00    13.00
# 3             United Kingdom Sam Ryder - Space Man    13.00   15.00     8.75
# 4                 Italy Mahmood & Blanco - Brividi    41.00   51.00    14.00
# 5      Norway Subwoolfer - Give That Wolf a Banana   101.00  101.00    73.00
# 6                            Poland Ochman - River   101.00  101.00    58.00
# 7              Serbia Konstrakta - In Corpore Sano    67.00  101.00    51.00
# 8            Greece Amanda Tenfjord - Die Together   101.00  101.00    69.00
# 9    Moldova Z. şi Zdub & A. Brothers - Trenuleţul   151.00   81.00   101.00
# 10                     Netherlands S10 - De Diepte   101.00  101.00    76.00
# ...

# %%
lista_corregida = []
for song in apuestas_2022['SONG']:

    if (str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]) in paises_dobleword:
        lista_corregida.append(paises_dobleword[(str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0])])
    else:
        lista_corregida.append((str(song.split(" ")).replace('\\xa0'," ").replace("'", '').strip('][').split(', ')[0].strip().split(" ")[0]))
        
apuestas_2022['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2022['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    else:
        lista_corregida.append(pais)
apuestas_2022['country'] = lista_corregida

# %%
lista_corregida = []
for pais in apuestas_2022['country']:
    if pais == '"':
        lista_corregida.append('Switzerland')
    else:
        lista_corregida.append(pais)
apuestas_2022['country'] = lista_corregida

# %%
codigo = []
for pais in apuestas_2022['country']:
    codigo.append(int(str(dict_codes[pais])+'2022'))
apuestas_2022['codigo'] = codigo

# %%
apuestas_2022.columns
# Out:
# Index(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
#        'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
#        'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
#        'STAN_JAMES', 'BWIN', 'MATCH_BOOK', 'country', 'codigo'],
#       dtype='object')

# %%
ap22_bets = apuestas_2022[['BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK']]

# %%
apuestas_2022['bet_mean'] = list(ap22_bets.mean(axis=1))

# %%
apuestas_2022.drop(['SONG', 'BET365', 'UNIBET', 'YOU_WIN', 'BOYLE_SPORTS', 'CORAL',
       'SKY_BET', 'BET_VICTOR', 'TITAN_BET', 'PAF', 'BETFAIR_SPORT',
       'SPORTING_BET', 'INTE_TOPS', 'PADDY_POWER', 'BET_FRED', 'BETWAY',
       'STAN_JAMES', 'BWIN', 'MATCH_BOOK'], axis=1, inplace=True)

# %%
apuestas_2022
# Out:
#                   country  codigo    bet_mean
# 0                 Ukraine  572022    1.336667
# 1                  Sweden  532022    6.076667
# 2                   Spain  522022   13.388889
# 3          United Kingdom  582022   13.986111
# 4                   Italy  342022   34.462778
# 5                  Norway  422022   77.111111
# 6                  Poland  432022   95.111111
# 7   Serbia and Montenegro  492022   99.277778
# 8                  Greece  292022  102.333333
# 9                 Moldova  382022  100.500000
# 10            Netherlands  552022  127.888889
# 11                Finland  252022  223.888889
# 12                Estonia  242022  220.823529
# 13              Australia  132022  239.944444
# 14         Czech Republic  222022  325.833333
# 15               Portugal  442022  335.277778
# 16                Armenia  122022  340.235294
# 17                Germany  282022  334.166667
# 18                 France  262022  363.333333
# ...

# %%
apuestas_2015.to_excel('../Apuestas_2015.xlsx')
apuestas_2016.to_excel('../Apuestas_2016.xlsx')
apuestas_2017.to_excel('../Apuestas_2017.xlsx')
apuestas_2018.to_excel('../Apuestas_2018.xlsx')
apuestas_2019.to_excel('../Apuestas_2019.xlsx')
apuestas_2021.to_excel('../Apuestas_2021.xlsx')
apuestas_2022.to_excel('../Apuestas_2022.xlsx')

# %% [markdown]
# ### Encantramos anteriores a 2015

# %% [markdown]
# ### 2002

# %%
import pandas as pd

apuestas_2002 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2002
# Out:
#     RANK  ODDS            COUNTRY                                     ENTRY  \
# 0      1   5/1         🇩🇪 Germany  Corinna May – I Can’t Live Without Music
# 1      2   6/1          🇸🇪 Sweden               Afro-dite – Never Let It Go
# 2      3   7/1         🇪🇪 Estonia                         Sahlene – Runaway
# 3      4   9/1  🇬🇧 United Kingdom               Jessica Garlick – Come Back
# 4      5  10/1         🇧🇪 Belgium              Sergio & The Ladies – Sister
# 5      6  12/1         🇦🇹 Austria                Manuel Ortega – Say A Word
# 6      7  12/1          🇫🇷 France      Sandrine François – Il faut du temps
# 7      8  14/1          🇨🇾 Cyprus                               One – Gimme
# 8      9  14/1         🇩🇰 Denmark              Malene – Tell Me Who You Are
# 9     10  14/1          🇱🇻 Latvia                         Marie N – I Wanna
# 10    11  14/1        🇸🇮 Slovenia                    Sestre – Samo ljubezen
# ...

# %%
apuestas_2002['country'] = [pais.split(" ")[1] for pais in apuestas_2002['COUNTRY']]

lista_corregida = []
for pais in apuestas_2002['country']:
    if pais == 'Netherlans':
        lista_corregida.append('The Netherlans')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    else:
        lista_corregida.append(pais)
apuestas_2002['country'] = lista_corregida

codigo = []
for pais in apuestas_2002['country']:
    codigo.append(int(str(dict_codes[pais])+'2002'))
apuestas_2002['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2002['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2002['bet_mean'] = lista_corregida

apuestas_2002.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2002
# Out:
#            country  codigo  bet_mean
# 0          Germany  282002       6.0
# 1           Sweden  532002       7.0
# 2          Estonia  242002       8.0
# 3   United Kingdom  582002      10.0
# 4          Belgium  172002      11.0
# 5          Austria  142002      13.0
# 6           France  262002      13.0
# 7           Cyprus  212002      15.0
# 8          Denmark  232002      15.0
# 9           Latvia  352002      15.0
# 10        Slovenia  512002      15.0
# 11           Spain  522002      15.0
# 12         Croatia  202002      17.0
# 13           Malta  372002      17.0
# 14          Russia  462002      17.0

# %% [markdown]
# ### 2003

# %%
apuestas_2003 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2003
# Out:
#     RANK  ODDS                  COUNTRY  \
# 0      1   7/2                🇷🇺 Russia
# 1      2   8/1               🇩🇪 Germany
# 2      3   8/1                🇱🇻 Latvia
# 3      4   8/1                 🇪🇸 Spain
# 4      5   8/1                🇸🇪 Sweden
# 5      6   9/1        🇬🇧 United Kingdom
# 6      7  14/1               🇮🇪 Ireland
# 7      8  14/1           🇳🇱 Netherlands
# 8      9  16/1               🇪🇪 Estonia
# 9     10  16/1                🇫🇷 France
# 10    11  16/1               🇮🇸 Iceland
# 11    12  20/1                🇳🇴 Norway
# 12    13  20/1               🇷🇴 Romania
# 13    14  25/1  🇧🇦 Bosnia & Herzegovina
# 14    15  25/1                🇬🇷 Greece
#
#                                              ENTRY EUROVISION_PLACING
# 0                    t.A.t.u. – Ne ver’, ne boysia                3rd
# 1                            Lou – Let’s Get Happy               11th
# 2                         F.L.Y. – Hello From Mars               24th
# ...

# %%
apuestas_2003['country'] = [pais.split(" ")[1] for pais in apuestas_2003['COUNTRY']]

lista_corregida = []
for pais in apuestas_2003['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    else:
        lista_corregida.append(pais)
apuestas_2003['country'] = lista_corregida

codigo = []
for pais in apuestas_2003['country']:
    codigo.append(int(str(dict_codes[pais])+'2003'))
apuestas_2003['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2003['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2003['bet_mean'] = lista_corregida

apuestas_2003.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2003
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COUNTRY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### 2004

# %%
apuestas_2004 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2004
# Out:
#     RANK  ODDS                   COUNTRY  \
# 0      1   6/1                 🇸🇪 Sweden
# 1      2  10/1                🇧🇪 Belgium
# 2      3  10/1                 🇨🇾 Cyprus
# 3      4  10/1                🇩🇪 Germany
# 4      5  10/1  🇷🇸🇲🇪 Serbia & Montenegro
# 5      6  12/1                 🇬🇷 Greece
# 6      7  12/1                  🇲🇹 Malta
# 7      8  12/1                 🇷🇺 Russia
# 8      9  12/1                 🇹🇷 Turkey
# 9     10  14/1                🇮🇪 Ireland
# 10    11  16/1                🇩🇰 Denmark
# 11    12  16/1                🇫🇮 Finland
# 12    13  16/1                  🇪🇸 Spain
# 13    14  16/1                🇺🇦 Ukraine
# 14    15  20/1                 🇫🇷 France
#
#                                                ENTRY EUROVISION_PLACING
# 0                         Lena Philipsson – It Hurts                5th
# 1                                    Xandee – 1 Life               22nd
# 2               Lisa Andreas – Stronger Every Minute                5th
# ...

# %%
apuestas_2004['country'] = [pais.split(" ")[1] for pais in apuestas_2004['COUNTRY']]

lista_corregida = []
for pais in apuestas_2004['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')    
    else:
        lista_corregida.append(pais)
apuestas_2004['country'] = lista_corregida

codigo = []
for pais in apuestas_2004['country']:
    codigo.append(int(str(dict_codes[pais])+'2004'))
apuestas_2004['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2004['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2004['bet_mean'] = lista_corregida

apuestas_2004.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2004
# Out:
#                   country  codigo  bet_mean
# 0                  Sweden  532004       7.0
# 1                 Belgium  172004      11.0
# 2                  Cyprus  212004      11.0
# 3                 Germany  282004      11.0
# 4   Serbia and Montenegro  492004      11.0
# 5                  Greece  292004      13.0
# 6                   Malta  372004      13.0
# 7                  Russia  462004      13.0
# 8                  Turkey  562004      13.0
# 9                 Ireland  322004      15.0
# 10                Denmark  232004      17.0
# 11                Finland  252004      17.0
# 12                  Spain  522004      17.0
# 13                Ukraine  572004      17.0
# 14                 France  262004      21.0

# %% [markdown]
# ### 2005

# %%
apuestas_2005 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2005
# Out:
#     RANK  ODDS                  COUNTRY  \
# 0      1  11/4                🇬🇷 Greece
# 1      2  11/2                🇳🇴 Norway
# 2      3   9/1               🇭🇺 Hungary
# 3      4   9/1               🇮🇸 Iceland
# 4      5   9/1           🇨🇭 Switzerland
# 5      6  12/1                 🇲🇹 Malta
# 6      7  16/1  🇧🇦 Bosnia & Herzegovina
# 7      8  20/1               🇧🇾 Belarus
# 8      9  20/1               🇪🇪 Estonia
# 9     10  20/1           🇳🇱 Netherlands
# 10    11  20/1        🇬🇧 United Kingdom
# 11    12  25/1                🇨🇾 Cyprus
# 12    13  25/1             🇱🇹 Lithuania
# 13    14  25/1                🇸🇪 Sweden
# 14    15  33/1               🇩🇰 Denmark
#
#                                     ENTRY EUROVISION_PLACING
# 0        Helena Paparizou – My Number One                1st
# 1                  Wig Wam – In My Dreams                9th
# 2                     NOX – Forogj, világ               12th
# 3              Selma – If I Had Your Love          SF (16th)
# ...

# %%
apuestas_2005['country'] = [pais.split(" ")[1] for pais in apuestas_2005['COUNTRY']]

lista_corregida = []
for pais in apuestas_2005['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')    
    else:
        lista_corregida.append(pais)
apuestas_2005['country'] = lista_corregida

codigo = []
for pais in apuestas_2005['country']:
    codigo.append(int(str(dict_codes[pais])+'2005'))
apuestas_2005['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2005['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2005['bet_mean'] = lista_corregida

apuestas_2005.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2005
# Out:
#                    country  codigo  bet_mean
# 0                   Greece  292005      3.75
# 1                   Norway  422005      6.50
# 2                  Hungary  302005     10.00
# 3                  Iceland  312005     10.00
# 4              Switzerland  542005     10.00
# 5                    Malta  372005     13.00
# 6   Bosnia and Herzegovina  182005     17.00
# 7                  Belarus  162005     21.00
# 8                  Estonia  242005     21.00
# 9          The Netherlands  552005     21.00
# 10          United Kingdom  582005     21.00
# 11                  Cyprus  212005     26.00
# 12               Lithuania  362005     26.00
# 13                  Sweden  532005     26.00
# 14                 Denmark  232005     34.00

# %% [markdown]
# ### 2006

# %%
apuestas_2006 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2006
# Out:
#     RANK  ODDS                  COUNTRY                                ENTRY  \
# 0      1   2/1                🇬🇷 Greece              Anna Vissi – Everything
# 1      2   7/1               🇷🇴 Romania           Mihai Trăistariu – Tornerò
# 2      3   8/1                🇸🇪 Sweden                  Carola – Invincible
# 3      4  12/1               🇧🇪 Belgium               Kate Ryan – Je t’adore
# 4      5  12/1  🇧🇦 Bosnia & Herzegovina               Hari Mata Hari – Lejla
# 5      6  12/1        🇬🇧 United Kingdom           Daz Sampson – Teenage Life
# 6      7  14/1               🇩🇪 Germany        Texas Lightning – No No Never
# 7      8  14/1                🇳🇴 Norway  Christine Guldbrandsen – Alvedansen
# 8      9  14/1           🇨🇭 Switzerland    six4one – If We All Give A Little
# 9     10  16/1               🇭🇷 Croatia               Severina – Moja štikla
# 10    11  20/1      🇲🇰 F.Y.R. Macedonia           Elena Risteska – Ninanajna
# ...

# %%
apuestas_2006['country'] = [pais.split(" ")[1] for pais in apuestas_2006['COUNTRY']]

lista_corregida = []
for pais in apuestas_2006['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2006['country'] = lista_corregida

codigo = []
for pais in apuestas_2006['country']:
    codigo.append(int(str(dict_codes[pais])+'2006'))
apuestas_2006['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2006['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2006['bet_mean'] = lista_corregida

apuestas_2006.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2006
# Out:
#                    country  codigo  bet_mean
# 0                   Greece  292006       3.0
# 1                  Romania  452006       8.0
# 2                   Sweden  532006       9.0
# 3                  Belgium  172006      13.0
# 4   Bosnia and Herzegovina  182006      13.0
# 5           United Kingdom  582006      13.0
# 6                  Germany  282006      15.0
# 7                   Norway  422006      15.0
# 8              Switzerland  542006      15.0
# 9                  Croatia  202006      17.0
# 10         North Macedonia  412006      21.0
# 11                 Finland  252006      23.0
# 12                 Denmark  232006      26.0
# 13                 Iceland  312006      26.0
# 14                   Malta  372006      26.0

# %% [markdown]
# ### 2007

# %%
apuestas_2007 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2007
# Out:
#     RANK  ODDS            COUNTRY  \
# 0      1   5/1     🇨🇭 Switzerland
# 1      2   7/1          🇸🇪 Sweden
# 2      3   8/1          🇷🇸 Serbia
# 3      4   8/1         🇧🇾 Belarus
# 4      5  11/1         🇺🇦 Ukraine
# 5      6  11/1        🇧🇬 Bulgaria
# 6      7  12/1          🇷🇺 Russia
# 7      8  14/1          🇬🇷 Greece
# 8      9  16/1         🇷🇴 Romania
# 9     10  16/1          🇨🇾 Cyprus
# 10    11  20/1        🇸🇮 Slovenia
# 11    12  20/1  🇬🇧 United Kingdom
# 12    13  20/1           🇲🇹 Malta
# 13    14  25/1          🇱🇻 Latvia
# 14    15  25/1           🇪🇸 Spain
#
#                                            ENTRY EUROVISION_PLACING
# 0                   DJ Bobo – Vampires Are Alive          SF (20th)
# 1                    The Ark – The Worrying Kind               18th
# 2                     Marija Šerifović – Molitva                1st
# 3                       Koldun – Work Your Magic                6th
# ...

# %%
apuestas_2007['country'] = [pais.split(" ")[1] for pais in apuestas_2007['COUNTRY']]

lista_corregida = []
for pais in apuestas_2007['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2007['country'] = lista_corregida

codigo = []
for pais in apuestas_2006['country']:
    codigo.append(int(str(dict_codes[pais])+'2007'))
apuestas_2007['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2007['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2007['bet_mean'] = lista_corregida

apuestas_2007.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2007
# Out:
#                   country  codigo  bet_mean
# 0             Switzerland  292007       6.0
# 1                  Sweden  452007       8.0
# 2   Serbia and Montenegro  532007       9.0
# 3                 Belarus  172007       9.0
# 4                 Ukraine  182007      12.0
# 5                Bulgaria  582007      12.0
# 6                  Russia  282007      13.0
# 7                  Greece  422007      15.0
# 8                 Romania  542007      17.0
# 9                  Cyprus  202007      17.0
# 10               Slovenia  412007      21.0
# 11         United Kingdom  252007      21.0
# 12                  Malta  232007      21.0
# 13                 Latvia  312007      26.0
# 14                  Spain  372007      26.0

# %% [markdown]
# ### 2008

# %%
apuestas_2008 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2008
# Out:
#     RANK  ODDS                  COUNTRY  \
# 0      1   7/2                🇷🇺 Russia
# 1      2   9/2                🇷🇸 Serbia
# 2      3   5/1               🇮🇪 Ireland
# 3      4  11/2               🇦🇲 Armenia
# 4      5   7/1               🇺🇦 Ukraine
# 5      6   9/1                🇸🇪 Sweden
# 6      7  18/1              🇧🇬 Bulgaria
# 7      8  20/1                🇬🇷 Greece
# 8      9  20/1                 🇪🇸 Spain
# 9     10  22/1                🇫🇷 France
# 10    11  25/1  🇧🇦 Bosnia & Herzegovina
# 11    12  25/1                🇱🇻 Latvia
# 12    13  25/1                🇹🇷 Turkey
# 13    14  25/1           🇨🇭 Switzerland
# 14    15  25/1               🇷🇴 Romania
#
#                                            ENTRY EUROVISION_PLACING
# 0                           Dima Bilan – Believe                1st
# 1        Jelena Tomašević feat. Bora Dugić – Oro                6th
# 2      Dustin The Turkey – Irelande Douze Pointe          SF (15th)
# ...

# %%
apuestas_2008['country'] = [pais.split(" ")[1] for pais in apuestas_2008['COUNTRY']]

lista_corregida = []
for pais in apuestas_2008['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2008['country'] = lista_corregida

codigo = []
for pais in apuestas_2008['country']:
    codigo.append(int(str(dict_codes[pais])+'2008'))
apuestas_2008['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2008['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2008['bet_mean'] = lista_corregida

apuestas_2008.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2008
# Out:
#                    country  codigo  bet_mean
# 0                   Russia  462008       4.5
# 1    Serbia and Montenegro  492008       5.5
# 2                  Ireland  322008       6.0
# 3                  Armenia  122008       6.5
# 4                  Ukraine  572008       8.0
# 5                   Sweden  532008      10.0
# 6                 Bulgaria  192008      19.0
# 7                   Greece  292008      21.0
# 8                    Spain  522008      21.0
# 9                   France  262008      23.0
# 10  Bosnia and Herzegovina  182008      26.0
# 11                  Latvia  352008      26.0
# 12                  Turkey  562008      26.0
# 13             Switzerland  542008      26.0
# 14                 Romania  452008      26.0

# %% [markdown]
# ### 2009

# %%
apuestas_2009 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2009
# Out:
#     RANK  ODDS                  COUNTRY  \
# 0      1   6/4                🇳🇴 Norway
# 1      2   9/2                🇬🇷 Greece
# 2      3   8/1                🇹🇷 Turkey
# 3      4   8/1            🇲🇪 Montenegro
# 4      5  10/1            🇦🇿 Azerbaijan
# 5      6  12/1                🇸🇪 Sweden
# 6      7  14/1                 🇲🇹 Malta
# 7      8  18/1        🇬🇧 United Kingdom
# 8      9  25/1               🇪🇪 Estonia
# 9     10  25/1  🇧🇦 Bosnia & Herzegovina
# 10    11  25/1                🇫🇷 France
# 11    12  25/1                 🇪🇸 Spain
# 12    13  25/1                🇷🇺 Russia
# 13    14  33/1               🇫🇮 Finland
# 14    15  33/1               🇮🇸 Iceland
#
#                                                 ENTRY EUROVISION_PLACING
# 0                         Alexander Rybak – Fairytale                1st
# 1                    Sakis Rouvas – This Is Our Night                7th
# 2                                Hadise – Düm Tek Tek                4th
# ...

# %%
apuestas_2009['country'] = [pais.split(" ")[1] for pais in apuestas_2009['COUNTRY']]

lista_corregida = []
for pais in apuestas_2009['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2009['country'] = lista_corregida

codigo = []
for pais in apuestas_2009['country']:
    codigo.append(int(str(dict_codes[pais])+'2009'))
apuestas_2009['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2009['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2009['bet_mean'] = lista_corregida

apuestas_2009.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2009
# Out:
#                    country  codigo  bet_mean
# 0                   Norway  422009       2.5
# 1                   Greece  292009       5.5
# 2                   Turkey  562009       9.0
# 3               Montenegro  402009       9.0
# 4               Azerbaijan  152009      11.0
# 5                   Sweden  532009      13.0
# 6                    Malta  372009      15.0
# 7           United Kingdom  582009      19.0
# 8                  Estonia  242009      26.0
# 9   Bosnia and Herzegovina  182009      26.0
# 10                  France  262009      26.0
# 11                   Spain  522009      26.0
# 12                  Russia  462009      26.0
# 13                 Finland  252009      34.0
# 14                 Iceland  312009      34.0

# %%
apuestas_2010 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2010
# Out:
#     RANK  ODDS        COUNTRY                                         ENTRY  \
# 0      1  11/4     🇩🇪 Germany                              Lena – Satellite
# 1      2   7/2  🇦🇿 Azerbaijan                            Safura – Drip Drop
# 2      3   8/1      🇮🇱 Israel                           Harel Skaat – Milim
# 3      4  12/1     🇩🇰 Denmark  Chanée & N’evergreen – In A Moment Like This
# 4      5  14/1     🇦🇲 Armenia                     Eva Rivas – Apricot Stone
# 5      6  14/1     🇭🇷 Croatia                        Feminnem – Lako Je Sve
# 6      7  14/1      🇳🇴 Norway       Didrik Solli-Tangen – My Heart Is Yours
# 7      8  25/1      🇬🇷 Greece               Giorgos Alkaios & Friends – OPA
# 8      9  28/1      🇸🇪 Sweden             Anna Bergendahl – This Is My Life
# 9     10  33/1     🇧🇪 Belgium                   Tom Dice – Me And My Guitar
# 10    11  33/1     🇮🇪 Ireland                 Niamh Kavanagh – It’s For You
# ...

# %%
apuestas_2010['country'] = [pais.split(" ")[1] for pais in apuestas_2010['COUNTRY']]

lista_corregida = []
for pais in apuestas_2009['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2010['country'] = lista_corregida

codigo = []
for pais in apuestas_2010['country']:
    codigo.append(int(str(dict_codes[pais])+'2010'))
apuestas_2010['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2010['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2010['bet_mean'] = lista_corregida

apuestas_2010.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2010
# Out:
#                    country  codigo  bet_mean
# 0                   Norway  422010      3.75
# 1                   Greece  292010      4.50
# 2                   Turkey  562010      9.00
# 3               Montenegro  402010     13.00
# 4               Azerbaijan  152010     15.00
# 5                   Sweden  532010     15.00
# 6                    Malta  372010     15.00
# 7           United Kingdom  582010     26.00
# 8                  Estonia  242010     29.00
# 9   Bosnia and Herzegovina  182010     34.00
# 10                  France  262010     34.00
# 11                   Spain  522010     34.00
# 12                  Russia  462010     41.00
# 13                 Finland  252010     67.00
# 14                 Iceland  312010     67.00

# %% [markdown]
# ### 2011

# %%
apuestas_2011 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2011
# Out:
#     RANK  ODDS                  COUNTRY                               ENTRY  \
# 0      1   4/1                🇫🇷 France              Amaury Vassili – Sognu
# 1      2  13/2               🇪🇪 Estonia   Getter Jaani – Rockefeller Street
# 2      3   7/1        🇬🇧 United Kingdom                        Blue – I Can
# 3      4   8/1               🇭🇺 Hungary   Kati Wolf – What About My Dreams?
# 4      5  10/1                🇸🇪 Sweden                Eric Saade – Popular
# 5      6  10/1  🇧🇦 Bosnia & Herzegovina        Dino Merlin – Love In Rewind
# 6      7  12/1            🇦🇿 Azerbaijan        Ell & Nikki – Running Scared
# 7      8  12/1                🇳🇴 Norway           Stella Mwangi – Haba Haba
# 8      9  12/1               🇩🇪 Germany          Lena – Taken By A Stranger
# 9     10  20/1                🇷🇺 Russia           Alexej Vorobjov – Get You
# 10    11  20/1               🇮🇪 Ireland                  Jedward – Lipstick
# ...

# %%
apuestas_2011['country'] = [pais.split(" ")[1] for pais in apuestas_2011['COUNTRY']]

lista_corregida = []
for pais in apuestas_2011['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2011['country'] = lista_corregida

codigo = []
for pais in apuestas_2011['country']:
    codigo.append(int(str(dict_codes[pais])+'2011'))
apuestas_2011['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2011['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2011['bet_mean'] = lista_corregida

apuestas_2011.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2011
# Out:
#                    country  codigo  bet_mean
# 0                   France  262011       5.0
# 1                  Estonia  242011       7.5
# 2           United Kingdom  582011       8.0
# 3                  Hungary  302011       9.0
# 4                   Sweden  532011      11.0
# 5   Bosnia and Herzegovina  182011      11.0
# 6               Azerbaijan  152011      13.0
# 7                   Norway  422011      13.0
# 8                  Germany  282011      13.0
# 9                   Russia  462011      21.0
# 10                 Ireland  322011      21.0
# 11                 Denmark  232011      21.0
# 12                   Italy  342011      34.0
# 13                 Romania  452011      41.0
# 14                  Poland  432011      41.0

# %% [markdown]
# ### 2012

# %%
apuestas_2012 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2012
# Out:
#     RANK  ODDS            COUNTRY  \
# 0      1   9/4          🇸🇪 Sweden
# 1      2   8/1           🇮🇹 Italy
# 2      3  10/1          🇷🇺 Russia
# 3      4  11/1          🇷🇸 Serbia
# 4      5  14/1         🇩🇰 Denmark
# 5      6  14/1  🇬🇧 United Kingdom
# 6      7  16/1         🇮🇪 Ireland
# 7      8  18/1           🇪🇸 Spain
# 8      9  20/1         🇩🇪 Germany
# 9     10  20/1          🇳🇴 Norway
# 10    11  22/1         🇮🇸 Iceland
# 11    12  25/1          🇬🇷 Greece
# 12    13  28/1         🇷🇴 Romania
# 13    14  28/1          🇹🇷 Turkey
# 14    15  33/1          🇨🇾 Cyprus
#
#                                              ENTRY EUROVISION_PLACING
# 0                                Loreen – Euphoria                1st
# 1     Nina Zilli – L’amore è femmina (Out Of Love)                9th
# 2      Buranovskiye Babushki – Party For Everybody                2nd
# 3            Željko Joksimović – Nije Ljubav Stvar                3rd
# ...

# %%
apuestas_2012['country'] = [pais.split(" ")[1] for pais in apuestas_2012['COUNTRY']]

lista_corregida = []
for pais in apuestas_2012['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    else:
        lista_corregida.append(pais)
apuestas_2012['country'] = lista_corregida

codigo = []
for pais in apuestas_2012['country']:
    codigo.append(int(str(dict_codes[pais])+'2012'))
apuestas_2012['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2012['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2012['bet_mean'] = lista_corregida

apuestas_2012.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2012
# Out:
#                   country  codigo  bet_mean
# 0                  Sweden  532012      3.25
# 1                   Italy  342012      9.00
# 2                  Russia  462012     11.00
# 3   Serbia and Montenegro  492012     12.00
# 4                 Denmark  232012     15.00
# 5          United Kingdom  582012     15.00
# 6                 Ireland  322012     17.00
# 7                   Spain  522012     19.00
# 8                 Germany  282012     21.00
# 9                  Norway  422012     21.00
# 10                Iceland  312012     23.00
# 11                 Greece  292012     26.00
# 12                Romania  452012     29.00
# 13                 Turkey  562012     29.00
# 14                 Cyprus  212012     34.00

# %% [markdown]
# ### 2013

# %%
apuestas_2013 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2013
# Out:
#     RANK  ODDS            COUNTRY  \
# 0      1   6/4         🇩🇰 Denmark
# 1      2   8/1          🇳🇴 Norway
# 2      3  12/1         🇺🇦 Ukraine
# 3      4  16/1          🇷🇺 Russia
# 4      5  16/1          🇸🇪 Sweden
# 5      6  19/1     🇳🇱 Netherlands
# 6      7  25/1         🇩🇪 Germany
# 7      8  25/1         🇬🇪 Georgia
# 8      9  25/1           🇮🇹 Italy
# 9     10  33/1      🇦🇿 Azerbaijan
# 10    11  40/1      🇸🇲 San Marino
# 11    12  50/1  🇬🇧 United Kingdom
# 12    13  66/1         🇮🇪 Ireland
# 13    14  66/1         🇧🇾 Belarus
# 14    15  75/1          🇬🇷 Greece
#
#                                                 ENTRY EUROVISION_PLACING
# 0                  Emmelie de Forest – Only Teardrops                1st
# 1                Margaret Berger – I Feed You My Love                4th
# 2                            Zlata Ognevich – Gravity                3rd
# 3                             Dina Garipova – What If                5th
# ...

# %%
apuestas_2013['country'] = [pais.split(" ")[1] for pais in apuestas_2013['COUNTRY']]

lista_corregida = []
for pais in apuestas_2013['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    elif pais == 'San':
        lista_corregida.append('San Marino')
    else:
        lista_corregida.append(pais)
apuestas_2013['country'] = lista_corregida

codigo = []
for pais in apuestas_2013['country']:
    codigo.append(int(str(dict_codes[pais])+'2013'))
apuestas_2013['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2013['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2013['bet_mean'] = lista_corregida

apuestas_2013.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2013
# Out:
#             country  codigo  bet_mean
# 0           Denmark  232013       2.5
# 1            Norway  422013       9.0
# 2           Ukraine  572013      13.0
# 3            Russia  462013      17.0
# 4            Sweden  532013      17.0
# 5   The Netherlands  552013      20.0
# 6           Germany  282013      26.0
# 7           Georgia  272013      26.0
# 8             Italy  342013      26.0
# 9        Azerbaijan  152013      34.0
# 10       San Marino  472013      41.0
# 11   United Kingdom  582013      51.0
# 12          Ireland  322013      67.0
# 13          Belarus  162013      67.0
# 14           Greece  292013      76.0

# %% [markdown]
# ### 2014

# %%
apuestas_2014 = pd.read_clipboard(header=None, names=['RANK','ODDS', 'COUNTRY', 'ENTRY','EUROVISION_PLACING'])
apuestas_2014
# Out:
#     RANK  ODDS            COUNTRY                                     ENTRY  \
# 0      1   6/4         🇦🇲 Armenia                      Aram MP3 – Not Alone
# 1      2  11/2          🇸🇪 Sweden                      Sanna Nielsen – Undo
# 2      3  12/1         🇩🇰 Denmark                  Basim – Cliché Love Song
# 3      4  12/1          🇳🇴 Norway                 Carl Espen – Silent Storm
# 4      5  18/1         🇭🇺 Hungary          András Kállay-Saunders – Running
# 5      6  20/1  🇬🇧 United Kingdom          Molly – Children Of The Universe
# 6      7  20/1         🇺🇦 Ukraine              Mariya Yaremchuk – Tick-Tock
# 7      8  20/1      🇦🇿 Azerbaijan            Dilara Kazimova – Start A Fire
# 8      9  25/1         🇧🇪 Belgium                     Axel Hirsoux – Mother
# 9     10  25/1         🇷🇴 Romania              Paula Seling & OVI – Miracle
# 10    11  40/1          🇷🇺 Russia                Tolmachevy Sisters – Shine
# ...

# %%
apuestas_2014['country'] = [pais.split(" ")[1] for pais in apuestas_2014['COUNTRY']]

lista_corregida = []
for pais in apuestas_2014['country']:
    if pais == 'Netherlands':
        lista_corregida.append('The Netherlands')
    elif pais == 'United':
        lista_corregida.append('United Kingdom')
    elif pais == 'Bosnia':
        lista_corregida.append('Bosnia and Herzegovina')
    elif pais == 'Serbia':
        lista_corregida.append('Serbia and Montenegro')
    elif pais == 'F.Y.R.':
        lista_corregida.append('North Macedonia')
    elif pais == 'San':
        lista_corregida.append('San Marino')
    else:
        lista_corregida.append(pais)
apuestas_2014['country'] = lista_corregida

codigo = []
for pais in apuestas_2014['country']:
    codigo.append(int(str(dict_codes[pais])+'2014'))
apuestas_2014['codigo'] = codigo

lista_corregida = []
for odd in apuestas_2014['ODDS']:
    lista_corregida.append( int(odd.split('/')[0]) / int(odd.split('/')[1]) + 1 )
apuestas_2014['bet_mean'] = lista_corregida

apuestas_2014.drop(['RANK','ODDS','COUNTRY','ENTRY','EUROVISION_PLACING'], axis=1, inplace=True)

apuestas_2014
# Out:
#            country  codigo  bet_mean
# 0          Armenia  122014       2.5
# 1           Sweden  532014       6.5
# 2          Denmark  232014      13.0
# 3           Norway  422014      13.0
# 4          Hungary  302014      19.0
# 5   United Kingdom  582014      21.0
# 6          Ukraine  572014      21.0
# 7       Azerbaijan  152014      21.0
# 8          Belgium  172014      26.0
# 9          Romania  452014      26.0
# 10          Russia  462014      41.0
# 11           Italy  342014      67.0
# 12          Greece  292014      67.0
# 13          Israel  332014      67.0
# 14         Ireland  322014      67.0

# %%
apuestas_2002.to_excel('../Apuestas_2002.xlsx')
apuestas_2003.to_excel('../Apuestas_2003.xlsx')
apuestas_2004.to_excel('../Apuestas_2004.xlsx')
apuestas_2005.to_excel('../Apuestas_2005.xlsx')
apuestas_2006.to_excel('../Apuestas_2006.xlsx')
apuestas_2007.to_excel('../Apuestas_2007.xlsx')
apuestas_2008.to_excel('../Apuestas_2008.xlsx')
apuestas_2009.to_excel('../Apuestas_2009.xlsx')
apuestas_2010.to_excel('../Apuestas_2010.xlsx')
apuestas_2011.to_excel('../Apuestas_2011.xlsx')
apuestas_2012.to_excel('../Apuestas_2012.xlsx')
apuestas_2013.to_excel('../Apuestas_2013.xlsx')
apuestas_2014.to_excel('../Apuestas_2014.xlsx')

# %%
dfs = [apuestas_2002, apuestas_2003, apuestas_2004, apuestas_2005, apuestas_2006, apuestas_2007, apuestas_2008,
       apuestas_2009, apuestas_2010, apuestas_2011, apuestas_2012, apuestas_2013, apuestas_2014, apuestas_2015,
       apuestas_2016, apuestas_2017, apuestas_2018, apuestas_2019, apuestas_2021, apuestas_2022]

# %%
apuestas_2002_2022 = pd.concat(dfs, axis=0)

# %%
apuestas_2002_2022.to_excel('../Apuestas_TOTAL.xlsx')
